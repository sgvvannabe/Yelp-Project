# %%
import json
import numpy as np 
import pandas as pd
pd.options.display.max_columns = 999
pd.set_option('display.max_rows', 1500)

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import re, string, ast

# %%
# Define functions to read massive (~7gb) json file
def init_ds(json):
    ds= {}
    keys = json.keys()
    for k in keys:
        ds[k]= []
    return ds, keys

def read_json(file):
    dataset = {}
    keys = []
    with open(file) as file_lines:
        for count, line in enumerate(file_lines):
            data = json.loads(line.strip())
            if count == 0:
                dataset, keys = init_ds(data)
            for k in keys:
                dataset[k].append(data[k])
                
        return pd.DataFrame(dataset)

# %% [markdown]
# # Handling Reviews JSON data

# %%
# Load the review json
df_review = read_json('../input/d/yelp-dataset/yelp-dataset/yelp_academic_dataset_review.json')

# %% [markdown]
# This on my machine took about ~10 gb ram

# %%
# Take a look at the review dataframe
df_review.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  lWC-xP3rd6obsecCYsGZRg  ak0TdVmGKo4pwqdJSTLwWw  buF9druCkbuXLX526sGELQ
# 1  8bFej1QE5LXp4O05qjGqXA  YoVfDbnISlW0f7abNQACIg  RA4V8pr014UyUbDvI-LW2A
# 2  NDhkzczKjLshODbqDoNLSg  eC5evKn1TWDyHCyQAwguUw  _sS2LBIGNT5NQb6PD1Vtjw
# 3  T5fAqjjFooT4V0OeZyuk1w  SFQ1jcnGguO0LYWnbbftAA  0AzLzHfOJgL7ROwhdww2ew
# 4  sjm_uUcQVxab_EeLCqsYLg  0kA0PAJ8QFMeveQWHFqz2A  8zehGz9jnxPqXtOc7KaJxA
#
#    stars  useful  funny  cool  \
# 0    4.0       3      1     1
# 1    4.0       1      0     0
# 2    5.0       0      0     0
# 3    2.0       1      1     1
# 4    4.0       0      0     0
#
#                                                 text                 date
# 0  Apparently Prides Osteria had a rough summer a...  2014-10-11 03:34:02
# 1  This store is pretty good. Not as great as Wal...  2015-07-03 20:38:25
# 2  I called WVM on the recommendation of a couple...  2013-05-28 20:38:06
# 3  I've stayed at many Marriott and Renaissance M...  2010-01-08 02:29:15
# 4  The food is always great here. The service fro...  2011-07-28 18:05:01

# %%
# Drop columns that are not necesary
df_review.drop(['review_id', 'user_id', 'useful', 'funny', 'cool', 'date'], axis=1, inplace=True)

# %% [markdown]
# ### Review dataframe are used to narrow down businesses that are only restaurants.

# %%
# How many reviews are there?
print('There are total of {} reviews in the raw Yelp dataset'.format(len(df_review)))
# Out:
# There are total of 8635403 reviews in the raw Yelp dataset

# %%
# Filter reviews for text if it contains either the word 'food' or 'restaurant'
df_review = df_review[df_review['text'].str.contains('food|restaurant', flags=re.IGNORECASE, regex=True)]

# %%
# How many reviews are there afterwards?
print('There are total of {} reviews in the raw Yelp dataset that contain either food or restaurant in the review text'.format(len(df_review)))
# Out:
# There are total of 3419499 reviews in the raw Yelp dataset that contain either food or restaurant in the review text

# %%
df_review.head()
# Out:
#                business_id  stars  \
# 0   buF9druCkbuXLX526sGELQ    4.0
# 4   8zehGz9jnxPqXtOc7KaJxA    4.0
# 6   EXOsmAB1s71WePlQk0WZrA    2.0
# 9   EEHhKSxUvJkoPSzeGKkpVg    5.0
# 10  WQFn1A7-UAA4JT5YWiop_w    1.0
#
#                                                  text
# 0   Apparently Prides Osteria had a rough summer a...
# 4   The food is always great here. The service fro...
# 6   The setting is perfectly adequate, and the foo...
# 9   I work in the Pru and this is the most afforda...
# 10  They NEVER seem to get our \norder correct, se...

# %%
# Get unique business ids
possible_restaurants = df_review['business_id'].unique()

# %% [markdown]
# # Handling Business JSON data

# %%
# Load the review json
df_business = read_json('../input/d/yelp-dataset/yelp-dataset/yelp_academic_dataset_business.json')

# %%
# Take a look at the business dataframe
df_business.head()
# Out:
#               business_id                     name              address  \
# 0  6iYb2HFDywm3zjuRg0shjw      Oskar Blues Taproom         921 Pearl St
# 1  tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX  7000 NE Airport Way
# 2  bvN78flM8NLprQ1a1y5dRg           The Reclaimory   4720 Hawthorne Ave
# 3  oaepsyvc0J17qwi8cfrOWg              Great Clips   2566 Enterprise Rd
# 4  PE9uqAjdw0E4-8mjGl3wVA        Crossfit Terminus  1046 Memorial Dr SE
#
#           city state postal_code   latitude   longitude  stars  review_count  \
# 0      Boulder    CO       80302  40.017544 -105.283348    4.0            86
# 1     Portland    OR       97218  45.588906 -122.593331    4.0           126
# 2     Portland    OR       97214  45.511907 -122.613693    4.5            13
# 3  Orange City    FL       32763  28.914482  -81.295979    3.0             8
# 4      Atlanta    GA       30316  33.747027  -84.353424    4.0            14
#
#    is_open                                         attributes  \
# 0        1  {'RestaurantsTableService': 'True', 'WiFi': 'u...
# 1        1  {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 2        1  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 3        1  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 4        1  {'GoodForKids': 'False', 'BusinessParking': '{...
#
#                                           categories  \
# 0  Gastropubs, Food, Beer Gardens, Restaurants, B...
# 1  Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 2  Antiques, Fashion, Used, Vintage & Consignment...
# 3                         Beauty & Spas, Hair Salons
# 4  Gyms, Active Life, Interval Training Gyms, Fit...
#
#                                                hours
# 0  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 1  {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 2  {'Thursday': '11:0-18:0', 'Friday': '11:0-18:0...
# 3                                               None
# 4  {'Monday': '16:0-19:0', 'Tuesday': '16:0-19:0'...

# %% [markdown]
# ##### For the attributes, different code will have to be executed to bring out the true values of the nested jsons. For the categories, since it's list of words separated by commas, NLP will be implemented.

# %%
# Re-load business.json in a list format
df_business = [json.loads(line) for line in open('../input/d/yelp-dataset/yelp-dataset/yelp_academic_dataset_business.json', 'r')]

# Normalize the df_business json
df_business = pd.json_normalize(df_business)

# %%
# Take a look at the un-nested business dataframe
df_business.head()
# Out:
#               business_id                     name              address  \
# 0  6iYb2HFDywm3zjuRg0shjw      Oskar Blues Taproom         921 Pearl St
# 1  tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX  7000 NE Airport Way
# 2  bvN78flM8NLprQ1a1y5dRg           The Reclaimory   4720 Hawthorne Ave
# 3  oaepsyvc0J17qwi8cfrOWg              Great Clips   2566 Enterprise Rd
# 4  PE9uqAjdw0E4-8mjGl3wVA        Crossfit Terminus  1046 Memorial Dr SE
#
#           city state postal_code   latitude   longitude  stars  review_count  \
# 0      Boulder    CO       80302  40.017544 -105.283348    4.0            86
# 1     Portland    OR       97218  45.588906 -122.593331    4.0           126
# 2     Portland    OR       97214  45.511907 -122.613693    4.5            13
# 3  Orange City    FL       32763  28.914482  -81.295979    3.0             8
# 4      Atlanta    GA       30316  33.747027  -84.353424    4.0            14
#
#    is_open                                         categories  \
# 0        1  Gastropubs, Food, Beer Gardens, Restaurants, B...
# 1        1  Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 2        1  Antiques, Fashion, Used, Vintage & Consignment...
# 3        1                         Beauty & Spas, Hair Salons
# 4        1  Gyms, Active Life, Interval Training Gyms, Fit...
#
#   attributes.RestaurantsTableService attributes.WiFi attributes.BikeParking  \
# 0                               True         u'free'                   True
# 1                                NaN         u'free'                  False
# 2                                NaN             NaN                  False
# 3                                NaN             NaN                    NaN
# 4                                NaN             NaN                    NaN
#
#                           attributes.BusinessParking  \
# 0  {'garage': False, 'street': True, 'validated':...
# 1  {'garage': True, 'street': False, 'validated':...
# 2  {'garage': False, 'street': True, 'validated':...
# 3                                                NaN
# 4  {'garage': False, 'street': False, 'validated'...
#
#   attributes.BusinessAcceptsCreditCards attributes.RestaurantsReservations  \
# 0                                  True                              False
# 1                                  True                              False
# 2                                  True                                NaN
# 3                                  True                                NaN
# 4                                  True                                NaN
#
#   attributes.WheelchairAccessible attributes.Caters attributes.OutdoorSeating  \
# 0                            True              True                      True
# 1                             NaN              True                     False
# 2                             NaN               NaN                       NaN
# 3                             NaN               NaN                       NaN
# 4                             NaN               NaN                       NaN
#
#   attributes.RestaurantsGoodForGroups attributes.HappyHour  \
# 0                                True                 True
# 1                               False                  NaN
# 2                                 NaN                  NaN
# 3                                 NaN                  NaN
# 4                                 NaN                  NaN
#
#   attributes.BusinessAcceptsBitcoin attributes.RestaurantsPriceRange2  \
# 0                             False                                 2
# 1                               NaN                                 2
# 2                               NaN                                 2
# 3                               NaN                                 1
# 4                               NaN                               NaN
#
#                                  attributes.Ambience attributes.HasTV  \
# 0  {'touristy': False, 'hipster': False, 'romanti...             True
# 1  {'romantic': False, 'intimate': False, 'touris...            False
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4                                                NaN              NaN
#
#   attributes.Alcohol                             attributes.GoodForMeal  \
# 0    'beer_and_wine'  {'dessert': False, 'latenight': False, 'lunch'...
# 1   u'beer_and_wine'  {'dessert': False, 'latenight': False, 'lunch'...
# 2                NaN                                                NaN
# 3                NaN                                                NaN
# 4                NaN                                                NaN
#
#   attributes.DogsAllowed attributes.RestaurantsTakeOut attributes.NoiseLevel  \
# 0                  False                          True            u'average'
# 1                    NaN                          True            u'average'
# 2                    NaN                           NaN                   NaN
# 3                    NaN                           NaN                   NaN
# 4                    NaN                           NaN                   NaN
#
#   attributes.RestaurantsAttire attributes.RestaurantsDelivery hours.Monday  \
# 0                     'casual'                           None    11:0-23:0
# 1                    u'casual'                          False     5:0-18:0
# 2                          NaN                            NaN          NaN
# 3                          NaN                            NaN          NaN
# 4                          NaN                            NaN    16:0-19:0
#
#   hours.Tuesday hours.Wednesday hours.Thursday hours.Friday hours.Saturday  \
# 0     11:0-23:0       11:0-23:0      11:0-23:0    11:0-23:0      11:0-23:0
# 1      5:0-17:0        5:0-18:0       5:0-18:0     5:0-18:0       5:0-18:0
# 2           NaN             NaN      11:0-18:0    11:0-18:0      11:0-18:0
# 3           NaN             NaN            NaN          NaN            NaN
# 4     16:0-19:0       16:0-19:0      16:0-19:0    16:0-19:0       9:0-11:0
#
#   hours.Sunday attributes.GoodForKids attributes.ByAppointmentOnly  hours  \
# 0    11:0-23:0                    NaN                          NaN    NaN
# 1     5:0-18:0                   True                        False    NaN
# 2    11:0-18:0                    NaN                        False    NaN
# 3          NaN                   True                        False    NaN
# 4          NaN                  False                          NaN    NaN
#
#   attributes.AcceptsInsurance  attributes attributes.HairSpecializesIn  \
# 0                         NaN         NaN                          NaN
# 1                         NaN         NaN                          NaN
# 2                         NaN         NaN                          NaN
# 3                         NaN         NaN                          NaN
# 4                         NaN         NaN                          NaN
#
#   attributes.GoodForDancing attributes.BestNights attributes.Music  \
# 0                       NaN                   NaN              NaN
# 1                       NaN                   NaN              NaN
# 2                       NaN                   NaN              NaN
# 3                       NaN                   NaN              NaN
# 4                       NaN                   NaN              NaN
#
#   attributes.BYOB attributes.CoatCheck attributes.Smoking  \
# 0             NaN                  NaN                NaN
# 1             NaN                  NaN                NaN
# 2             NaN                  NaN                NaN
# 3             NaN                  NaN                NaN
# 4             NaN                  NaN                NaN
#
#   attributes.DriveThru attributes.BYOBCorkage attributes.Corkage  \
# 0                  NaN                    NaN                NaN
# 1                  NaN                    NaN                NaN
# 2                  NaN                    NaN                NaN
# 3                  NaN                    NaN                NaN
# 4                  NaN                    NaN                NaN
#
#   attributes.RestaurantsCounterService attributes.AgesAllowed  \
# 0                                  NaN                    NaN
# 1                                  NaN                    NaN
# 2                                  NaN                    NaN
# 3                                  NaN                    NaN
# 4                                  NaN                    NaN
#
#   attributes.DietaryRestrictions attributes.Open24Hours
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                            NaN                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN

# %% [markdown]
# As it can be seen some of the columns (eg. attributes.BusinessParking) still have nested JSON format

# %%
# How many businesses in the dataset?
print('There are {} in the business in the Yelp dataset'.format(len(df_business)))
# Out:
# There are 160585 in the business in the Yelp dataset

# %%
# First only keep necessary columns
attributes_list = [col for col in df_business.columns if 'attributes' in col]
keep_cols = ['is_open', 'business_id', 'name', 'stars', 'review_count', 'categories']
keep_cols.extend(attributes_list)
df_business = df_business[keep_cols].copy()

# %%
# Filter df_business to only contain business_id's that are possibly restaurants
df_business = df_business[df_business['business_id'].isin(possible_restaurants)]

# Filter df_business to only contain businesses where categories are under food, restaurant, and/or bar
df_business = df_business[df_business['categories'].str.contains('food|restaurant|bar', flags=re.IGNORECASE, na=False)]

df_business.reset_index(drop=True, inplace=True)

# %%
# How many restaurants in the dataset?
print('There are possibly {} in the restaurants in the Yelp dataset'.format(len(df_business)))
# Out:
# There are possibly 61328 in the restaurants in the Yelp dataset

# %%
df_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61328 entries, 0 to 61327
# Data columns (total 46 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   is_open                                61328 non-null  int64
#  1   business_id                            61328 non-null  object
#  2   name                                   61328 non-null  object
#  3   stars                                  61328 non-null  float64
#  4   review_count                           61328 non-null  int64
#  5   categories                             61328 non-null  object
#  6   attributes.RestaurantsTableService     19197 non-null  object
#  7   attributes.WiFi                        42389 non-null  object
#  8   attributes.BikeParking                 43103 non-null  object
#  9   attributes.BusinessParking             55834 non-null  object
#  10  attributes.BusinessAcceptsCreditCards  49757 non-null  object
#  11  attributes.RestaurantsReservations     44757 non-null  object
#  12  attributes.WheelchairAccessible        15688 non-null  object
#  13  attributes.Caters                      38628 non-null  object
#  14  attributes.OutdoorSeating              47929 non-null  object
#  15  attributes.RestaurantsGoodForGroups    44043 non-null  object
#  16  attributes.HappyHour                   14603 non-null  object
#  17  attributes.BusinessAcceptsBitcoin      7200 non-null   object
#  18  attributes.RestaurantsPriceRange2      54353 non-null  object
#  19  attributes.Ambience                    42804 non-null  object
#  20  attributes.HasTV                       43190 non-null  object
#  21  attributes.Alcohol                     43106 non-null  object
#  22  attributes.GoodForMeal                 29127 non-null  object
#  23  attributes.DogsAllowed                 13215 non-null  object
#  24  attributes.RestaurantsTakeOut          53877 non-null  object
#  25  attributes.NoiseLevel                  37852 non-null  object
#  26  attributes.RestaurantsAttire           40318 non-null  object
#  27  attributes.RestaurantsDelivery         50272 non-null  object
#  28  attributes.GoodForKids                 43027 non-null  object
#  29  attributes.ByAppointmentOnly           4937 non-null   object
#  30  attributes.AcceptsInsurance            36 non-null     object
#  31  attributes                             0 non-null      float64
#  32  attributes.HairSpecializesIn           29 non-null     object
#  33  attributes.GoodForDancing              4499 non-null   object
#  34  attributes.BestNights                  5232 non-null   object
#  35  attributes.Music                       6694 non-null   object
#  36  attributes.BYOB                        3477 non-null   object
#  37  attributes.CoatCheck                   4755 non-null   object
#  38  attributes.Smoking                     4012 non-null   object
#  39  attributes.DriveThru                   5486 non-null   object
#  40  attributes.BYOBCorkage                 3654 non-null   object
#  41  attributes.Corkage                     3944 non-null   object
#  42  attributes.RestaurantsCounterService   40 non-null     object
#  43  attributes.AgesAllowed                 56 non-null     object
#  44  attributes.DietaryRestrictions         67 non-null     object
#  45  attributes.Open24Hours                 33 non-null     object
# dtypes: float64(2), int64(2), object(42)
# memory usage: 21.5+ MB

# %%
# Fill attributes NaN value with "Not listed"
df_business[attributes_list] = df_business[attributes_list].fillna('Not listed')

# %% [markdown]
# #### The restaurant owners had the option to list or not list these attributes options.

# %%
# Search through the columns to find out which columns contain nested JSON format
nested_cols = []

for col in df_business.columns:
    if (df_business[col].dtypes == 'object') | (df_business[col].dtypes == 'str'):
        if any(df_business[col].str.contains('{', na=False)):
            nested_cols.append(col)

nested_cols
# Out:
# ['attributes.BusinessParking',
#  'attributes.Ambience',
#  'attributes.GoodForMeal',
#  'attributes.HairSpecializesIn',
#  'attributes.BestNights',
#  'attributes.Music',
#  'attributes.DietaryRestrictions']

# %%
# Define a for loop fucntion to extract the information inside some of the attributes column

def attributes_extract(column):
    empty = "{'empty':'empty'}"
    result = pd.DataFrame()
    lst_dict = []
    global df_business
    
    # Create a loop to extract the information
    for row, value in df_business[column].items():
        if (value == 'Not listed') or (value == 'None'):
            temp_empty = ast.literal_eval(empty)
            lst_dict.append(temp_empty)

        else:
            temp_value = ast.literal_eval(value)
            lst_dict.append(temp_value)

    # Fill NaN and drop the 'empty' column
    result = result.append(lst_dict)
    result.fillna('Not listed', inplace=True)
    result.drop('empty', axis=1, inplace=True)

    # Rename the columns to include 'attributes' in the beginning
    for idx, col in enumerate(result.columns):
        result[col] = result[col].astype('str')
        result.rename(columns={col: ('attributes.' + col)}, inplace=True)

    # Drop the the column and concatenate extracted information to df_business dataframe
    df_business = pd.concat([df_business, result], axis=1)
    df_business.drop(column, axis=1, inplace=True)

# %%
# Un-nest the columns and add on to the business dataframe
for col in nested_cols:
    attributes_extract(col)

# %%
# Check to see if it worked correctly
df_business.head()
# Out:
#    is_open             business_id                     name  stars  \
# 0        1  6iYb2HFDywm3zjuRg0shjw      Oskar Blues Taproom    4.0
# 1        1  tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX    4.0
# 2        1  D4JtQNTI4X3KcbzacDJsMw      Bob Likes Thai Food    3.5
# 3        1  jFYIsSb7r1QeESVUnXPHBw          Boxwood Biscuit    4.5
# 4        1  HPA_qyMEddpAEtFof02ixg      Mr G's Pizza & Subs    4.0
#
#    review_count                                         categories  \
# 0            86  Gastropubs, Food, Beer Gardens, Restaurants, B...
# 1           126  Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 2           169                                  Restaurants, Thai
# 3            11                    Breakfast & Brunch, Restaurants
# 4            39                           Food, Pizza, Restaurants
#
#   attributes.RestaurantsTableService attributes.WiFi attributes.BikeParking  \
# 0                               True         u'free'                   True
# 1                         Not listed         u'free'                  False
# 2                         Not listed           u'no'                   True
# 3                         Not listed      Not listed             Not listed
# 4                              False         u'free'                   True
#
#   attributes.BusinessAcceptsCreditCards attributes.RestaurantsReservations  \
# 0                                  True                              False
# 1                                  True                              False
# 2                            Not listed                               True
# 3                            Not listed                         Not listed
# 4                                  True                              False
#
#   attributes.WheelchairAccessible attributes.Caters attributes.OutdoorSeating  \
# 0                            True              True                      True
# 1                      Not listed              True                     False
# 2                      Not listed             False                     False
# 3                      Not listed        Not listed                Not listed
# 4                            True              True                      True
#
#   attributes.RestaurantsGoodForGroups attributes.HappyHour  \
# 0                                True                 True
# 1                               False           Not listed
# 2                                True           Not listed
# 3                          Not listed           Not listed
# 4                                True           Not listed
#
#   attributes.BusinessAcceptsBitcoin attributes.RestaurantsPriceRange2  \
# 0                             False                                 2
# 1                        Not listed                                 2
# 2                        Not listed                                 2
# 3                        Not listed                        Not listed
# 4                             False                                 2
#
#   attributes.HasTV attributes.Alcohol attributes.DogsAllowed  \
# 0             True    'beer_and_wine'                  False
# 1            False   u'beer_and_wine'             Not listed
# 2            False            u'none'                  False
# 3       Not listed         Not listed             Not listed
# 4             True            u'none'                   True
#
#   attributes.RestaurantsTakeOut attributes.NoiseLevel  \
# 0                          True            u'average'
# 1                          True            u'average'
# 2                          True            u'average'
# 3                    Not listed            Not listed
# 4                          True             'average'
#
#   attributes.RestaurantsAttire attributes.RestaurantsDelivery  \
# 0                     'casual'                           None
# 1                    u'casual'                          False
# 2                    u'casual'                           True
# 3                   Not listed                     Not listed
# 4                    u'casual'                           True
#
#   attributes.GoodForKids attributes.ByAppointmentOnly  \
# 0             Not listed                   Not listed
# 1                   True                        False
# 2                   True                   Not listed
# 3             Not listed                   Not listed
# 4                   True                   Not listed
#
#   attributes.AcceptsInsurance  attributes attributes.GoodForDancing  \
# 0                  Not listed  Not listed                Not listed
# 1                  Not listed  Not listed                Not listed
# 2                  Not listed  Not listed                Not listed
# 3                  Not listed  Not listed                Not listed
# 4                  Not listed  Not listed                Not listed
#
#   attributes.BYOB attributes.CoatCheck attributes.Smoking  \
# 0      Not listed           Not listed         Not listed
# 1      Not listed           Not listed         Not listed
# 2      Not listed           Not listed         Not listed
# 3      Not listed           Not listed         Not listed
# 4      Not listed           Not listed         Not listed
#
#   attributes.DriveThru attributes.BYOBCorkage attributes.Corkage  \
# 0           Not listed             Not listed         Not listed
# 1           Not listed             Not listed         Not listed
# 2           Not listed             Not listed         Not listed
# 3           Not listed             Not listed         Not listed
# 4           Not listed             Not listed         Not listed
#
#   attributes.RestaurantsCounterService attributes.AgesAllowed  \
# 0                           Not listed             Not listed
# 1                           Not listed             Not listed
# 2                           Not listed             Not listed
# 3                           Not listed             Not listed
# 4                           Not listed             Not listed
#
#   attributes.Open24Hours attributes.garage attributes.street  \
# 0             Not listed             False              True
# 1             Not listed              True             False
# 2             Not listed             False              True
# 3             Not listed        Not listed        Not listed
# 4             Not listed             False             False
#
#   attributes.validated attributes.lot attributes.valet attributes.touristy  \
# 0                False          False            False               False
# 1                False          False            False               False
# 2                False          False            False               False
# 3           Not listed     Not listed       Not listed          Not listed
# 4                False           True            False               False
#
#   attributes.hipster attributes.romantic attributes.divey attributes.intimate  \
# 0              False               False            False               False
# 1              False               False            False               False
# 2              False               False            False               False
# 3         Not listed          Not listed       Not listed          Not listed
# 4              False               False            False               False
#
#   attributes.trendy attributes.upscale attributes.classy attributes.casual  \
# 0             False              False             False              True
# 1             False              False             False              True
# 2             False              False             False              True
# 3        Not listed         Not listed        Not listed        Not listed
# 4             False              False             False              True
#
#   attributes.dessert attributes.latenight attributes.lunch attributes.dinner  \
# 0              False                False            False             False
# 1              False                False             True             False
# 2              False                False             True              True
# 3         Not listed           Not listed       Not listed        Not listed
# 4         Not listed           Not listed       Not listed        Not listed
#
#   attributes.brunch attributes.breakfast attributes.straightperms  \
# 0             False                False               Not listed
# 1             False                 True               Not listed
# 2             False                False               Not listed
# 3        Not listed           Not listed               Not listed
# 4        Not listed           Not listed               Not listed
#
#   attributes.coloring attributes.extensions attributes.africanamerican  \
# 0          Not listed            Not listed                 Not listed
# 1          Not listed            Not listed                 Not listed
# 2          Not listed            Not listed                 Not listed
# 3          Not listed            Not listed                 Not listed
# 4          Not listed            Not listed                 Not listed
#
#   attributes.curly attributes.kids attributes.perms attributes.asian  \
# 0       Not listed      Not listed       Not listed       Not listed
# 1       Not listed      Not listed       Not listed       Not listed
# 2       Not listed      Not listed       Not listed       Not listed
# 3       Not listed      Not listed       Not listed       Not listed
# 4       Not listed      Not listed       Not listed       Not listed
#
#   attributes.monday attributes.tuesday attributes.friday attributes.wednesday  \
# 0        Not listed         Not listed        Not listed           Not listed
# 1        Not listed         Not listed        Not listed           Not listed
# 2        Not listed         Not listed        Not listed           Not listed
# 3        Not listed         Not listed        Not listed           Not listed
# 4        Not listed         Not listed        Not listed           Not listed
#
#   attributes.thursday attributes.sunday attributes.saturday attributes.dj  \
# 0          Not listed        Not listed          Not listed    Not listed
# 1          Not listed        Not listed          Not listed    Not listed
# 2          Not listed        Not listed          Not listed    Not listed
# 3          Not listed        Not listed          Not listed    Not listed
# 4          Not listed        Not listed          Not listed    Not listed
#
#   attributes.background_music attributes.no_music attributes.jukebox  \
# 0                  Not listed          Not listed         Not listed
# 1                  Not listed          Not listed         Not listed
# 2                  Not listed          Not listed         Not listed
# 3                  Not listed          Not listed         Not listed
# 4                  Not listed          Not listed         Not listed
#
#   attributes.live attributes.video attributes.karaoke attributes.dairy-free  \
# 0      Not listed       Not listed         Not listed            Not listed
# 1      Not listed       Not listed         Not listed            Not listed
# 2      Not listed       Not listed         Not listed            Not listed
# 3      Not listed       Not listed         Not listed            Not listed
# 4      Not listed       Not listed         Not listed            Not listed
#
#   attributes.gluten-free attributes.vegan attributes.kosher attributes.halal  \
# 0             Not listed       Not listed        Not listed       Not listed
# 1             Not listed       Not listed        Not listed       Not listed
# 2             Not listed       Not listed        Not listed       Not listed
# 3             Not listed       Not listed        Not listed       Not listed
# 4             Not listed       Not listed        Not listed       Not listed
#
#   attributes.soy-free attributes.vegetarian
# 0          Not listed            Not listed
# 1          Not listed            Not listed
# 2          Not listed            Not listed
# 3          Not listed            Not listed
# 4          Not listed            Not listed

# %%
# Reassign attributes_list
attributes_list = [col for col in df_business.columns if 'attributes' in col]

# Get list of columns where 'Not listed' (NaN) is >= 85% of the column values
dummy = []

for col in attributes_list:
    if df_business[col].value_counts(normalize=True)['Not listed'] >= 0.85:
        dummy.append(col)
dummy
# Out:
# ['attributes.BusinessAcceptsBitcoin',
#  'attributes.ByAppointmentOnly',
#  'attributes.AcceptsInsurance',
#  'attributes',
#  'attributes.GoodForDancing',
#  'attributes.BYOB',
#  'attributes.CoatCheck',
#  'attributes.Smoking',
#  'attributes.DriveThru',
#  'attributes.BYOBCorkage',
#  'attributes.Corkage',
#  'attributes.RestaurantsCounterService',
#  'attributes.AgesAllowed',
#  'attributes.Open24Hours',
#  'attributes.straightperms',
#  'attributes.coloring',
#  'attributes.extensions',
#  'attributes.africanamerican',
#  'attributes.curly',
#  'attributes.kids',
#  'attributes.perms',
#  'attributes.asian',
#  'attributes.monday',
#  'attributes.tuesday',
#  'attributes.friday',
#  'attributes.wednesday',
#  'attributes.thursday',
#  'attributes.sunday',
#  'attributes.saturday',
#  'attributes.dj',
#  'attributes.background_music',
#  'attributes.no_music',
#  'attributes.jukebox',
#  'attributes.live',
#  'attributes.video',
#  'attributes.karaoke',
#  'attributes.dairy-free',
#  'attributes.gluten-free',
#  'attributes.vegan',
#  'attributes.kosher',
#  'attributes.halal',
#  'attributes.soy-free',
#  'attributes.vegetarian']

# %%
# Drop those columns as it could be introducing too much noise into the data
df_business.drop(dummy, axis=1, inplace=True)

# %%
df_business.head()
# Out:
#    is_open             business_id                     name  stars  \
# 0        1  6iYb2HFDywm3zjuRg0shjw      Oskar Blues Taproom    4.0
# 1        1  tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX    4.0
# 2        1  D4JtQNTI4X3KcbzacDJsMw      Bob Likes Thai Food    3.5
# 3        1  jFYIsSb7r1QeESVUnXPHBw          Boxwood Biscuit    4.5
# 4        1  HPA_qyMEddpAEtFof02ixg      Mr G's Pizza & Subs    4.0
#
#    review_count                                         categories  \
# 0            86  Gastropubs, Food, Beer Gardens, Restaurants, B...
# 1           126  Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 2           169                                  Restaurants, Thai
# 3            11                    Breakfast & Brunch, Restaurants
# 4            39                           Food, Pizza, Restaurants
#
#   attributes.RestaurantsTableService attributes.WiFi attributes.BikeParking  \
# 0                               True         u'free'                   True
# 1                         Not listed         u'free'                  False
# 2                         Not listed           u'no'                   True
# 3                         Not listed      Not listed             Not listed
# 4                              False         u'free'                   True
#
#   attributes.BusinessAcceptsCreditCards attributes.RestaurantsReservations  \
# 0                                  True                              False
# 1                                  True                              False
# 2                            Not listed                               True
# 3                            Not listed                         Not listed
# 4                                  True                              False
#
#   attributes.WheelchairAccessible attributes.Caters attributes.OutdoorSeating  \
# 0                            True              True                      True
# 1                      Not listed              True                     False
# 2                      Not listed             False                     False
# 3                      Not listed        Not listed                Not listed
# 4                            True              True                      True
#
#   attributes.RestaurantsGoodForGroups attributes.HappyHour  \
# 0                                True                 True
# 1                               False           Not listed
# 2                                True           Not listed
# 3                          Not listed           Not listed
# 4                                True           Not listed
#
#   attributes.RestaurantsPriceRange2 attributes.HasTV attributes.Alcohol  \
# 0                                 2             True    'beer_and_wine'
# 1                                 2            False   u'beer_and_wine'
# 2                                 2            False            u'none'
# 3                        Not listed       Not listed         Not listed
# 4                                 2             True            u'none'
#
#   attributes.DogsAllowed attributes.RestaurantsTakeOut attributes.NoiseLevel  \
# 0                  False                          True            u'average'
# 1             Not listed                          True            u'average'
# 2                  False                          True            u'average'
# 3             Not listed                    Not listed            Not listed
# 4                   True                          True             'average'
#
#   attributes.RestaurantsAttire attributes.RestaurantsDelivery  \
# 0                     'casual'                           None
# 1                    u'casual'                          False
# 2                    u'casual'                           True
# 3                   Not listed                     Not listed
# 4                    u'casual'                           True
#
#   attributes.GoodForKids attributes.garage attributes.street  \
# 0             Not listed             False              True
# 1                   True              True             False
# 2                   True             False              True
# 3             Not listed        Not listed        Not listed
# 4                   True             False             False
#
#   attributes.validated attributes.lot attributes.valet attributes.touristy  \
# 0                False          False            False               False
# 1                False          False            False               False
# 2                False          False            False               False
# 3           Not listed     Not listed       Not listed          Not listed
# 4                False           True            False               False
#
#   attributes.hipster attributes.romantic attributes.divey attributes.intimate  \
# 0              False               False            False               False
# 1              False               False            False               False
# 2              False               False            False               False
# 3         Not listed          Not listed       Not listed          Not listed
# 4              False               False            False               False
#
#   attributes.trendy attributes.upscale attributes.classy attributes.casual  \
# 0             False              False             False              True
# 1             False              False             False              True
# 2             False              False             False              True
# 3        Not listed         Not listed        Not listed        Not listed
# 4             False              False             False              True
#
#   attributes.dessert attributes.latenight attributes.lunch attributes.dinner  \
# 0              False                False            False             False
# 1              False                False             True             False
# 2              False                False             True              True
# 3         Not listed           Not listed       Not listed        Not listed
# 4         Not listed           Not listed       Not listed        Not listed
#
#   attributes.brunch attributes.breakfast
# 0             False                False
# 1             False                 True
# 2             False                False
# 3        Not listed           Not listed
# 4        Not listed           Not listed

# %%
# Check for unique values in all of attribute columns
attributes_list = [col for col in df_business.columns if 'attributes' in col]

for col in attributes_list:
    print(df_business[col].unique())
# Out:
# ['True' 'Not listed' 'False' 'None']
# ["u'free'" "u'no'" 'Not listed' "'free'" "'no'" "u'paid'" "'paid'" 'None']
# ['True' 'False' 'Not listed' 'None']
# ['True' 'Not listed' 'False' 'None']
# ['False' 'True' 'Not listed' 'None']
# ['True' 'Not listed' 'False' 'None']
# ['True' 'False' 'Not listed' 'None']
# ['True' 'False' 'Not listed' 'None']
# ['True' 'False' 'Not listed' 'None']
# ['True' 'Not listed' 'False' 'None']
# ['2' 'Not listed' '1' '3' '4' 'None']
# ['True' 'False' 'Not listed' 'None']
# ["'beer_and_wine'" "u'beer_and_wine'" "u'none'" 'Not listed' "'none'"
#  "'full_bar'" "u'full_bar'" 'None']
# ['False' 'Not listed' 'True' 'None']
# ['True' 'Not listed' 'None' 'False']
# ["u'average'" 'Not listed' "'average'" "u'quiet'" "u'very_loud'" "'loud'"
#  "u'loud'" "'quiet'" "'very_loud'" 'None']
# ["'casual'" "u'casual'" 'Not listed' "u'dressy'" "u'formal'" "'dressy'"
#  'None' "'formal'"]
# ['None' 'False' 'True' 'Not listed']
# ['Not listed' 'True' 'False' 'None']
# ['False' 'True' 'Not listed']
# ['True' 'False' 'Not listed']
# ['False' 'Not listed' 'True']
# ['False' 'Not listed' 'True']
# ['False' 'Not listed' 'True']
# ['False' 'Not listed' 'True']
# ['False' 'Not listed' 'True']
# ['False' 'Not listed' 'True']
# ['False' 'Not listed' 'True']
# ['False' 'Not listed' 'True']
# ['False' 'Not listed' 'True']
# ['False' 'Not listed' 'True']
# ['False' 'Not listed' 'True']
# ['True' 'Not listed' 'False']
# ['False' 'Not listed' 'True']
# ['False' 'Not listed' 'True']
# ['False' 'True' 'Not listed']
# ['False' 'True' 'Not listed']
# ['False' 'Not listed' 'True']
# ['False' 'True' 'Not listed']

# %% [markdown]
# #### It seems like there were some data issues with original Yelp data (adding u infront of some of the values)

# %%
# Which columns contain u' infront of the values?
dummy = []
for col in attributes_list:
    if any(df_business[col].str.contains("u'")):
        print(col)
        dummy.append(col)
# Out:
# attributes.WiFi
# attributes.Alcohol
# attributes.NoiseLevel
# attributes.RestaurantsAttire

# %%
# Remove the character "u'" infront of the strings
for col in dummy:
    df_business[col] = df_business[col].str.replace("u'", "'")

# %% [markdown]
# The reason for replacing u' with ' is because values like u'loud will become lod if only replaced with u

# %%
# Check to see if the above worked
for col in dummy:
    print(df_business[col].unique())
# Out:
# ["'free'" "'no'" 'Not listed' "'paid'" 'None']
# ["'beer_and_wine'" "'none'" 'Not listed' "'full_bar'" 'None']
# ["'average'" 'Not listed' "'quiet'" "'very_loud'" "'loud'" 'None']
# ["'casual'" 'Not listed' "'dressy'" "'formal'" 'None']

# %% [markdown]
# ##### As shown above, it seems like original data had some of the NaN values be placed with 'None'. Previously, we've replaced all NaN with 'Not listed'. Replace these false 'None' with 'Not listed'

# %%
# Find out which columns have 'None'
none_cols = []

for col in attributes_list:
    if df_business[col].str.contains('None', flags=re.IGNORECASE).any():
        none_cols.append(col)

none_cols
# Out:
# ['attributes.RestaurantsTableService',
#  'attributes.WiFi',
#  'attributes.BikeParking',
#  'attributes.BusinessAcceptsCreditCards',
#  'attributes.RestaurantsReservations',
#  'attributes.WheelchairAccessible',
#  'attributes.Caters',
#  'attributes.OutdoorSeating',
#  'attributes.RestaurantsGoodForGroups',
#  'attributes.HappyHour',
#  'attributes.RestaurantsPriceRange2',
#  'attributes.HasTV',
#  'attributes.Alcohol',
#  'attributes.DogsAllowed',
#  'attributes.RestaurantsTakeOut',
#  'attributes.NoiseLevel',
#  'attributes.RestaurantsAttire',
#  'attributes.RestaurantsDelivery',
#  'attributes.GoodForKids']

# %%
# Take a look at one example column from above
df_business['attributes.RestaurantsTableService'].unique()
# Out:
# array(['True', 'Not listed', 'False', 'None'], dtype=object)

# %%
# Replace 'None' with 'Not listed'
for col in none_cols:
    df_business[col] = df_business[col].str.replace('None', 'Not listed', flags=re.IGNORECASE)

# %%
# Re-look at that example column to see if 'None' has been succesfully replaced
df_business['attributes.RestaurantsTableService'].unique()
# Out:
# array(['True', 'Not listed', 'False'], dtype=object)

# %%
# Check the dataframe
df_business.head()
# Out:
#    is_open             business_id                     name  stars  \
# 0        1  6iYb2HFDywm3zjuRg0shjw      Oskar Blues Taproom    4.0
# 1        1  tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX    4.0
# 2        1  D4JtQNTI4X3KcbzacDJsMw      Bob Likes Thai Food    3.5
# 3        1  jFYIsSb7r1QeESVUnXPHBw          Boxwood Biscuit    4.5
# 4        1  HPA_qyMEddpAEtFof02ixg      Mr G's Pizza & Subs    4.0
#
#    review_count                                         categories  \
# 0            86  Gastropubs, Food, Beer Gardens, Restaurants, B...
# 1           126  Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 2           169                                  Restaurants, Thai
# 3            11                    Breakfast & Brunch, Restaurants
# 4            39                           Food, Pizza, Restaurants
#
#   attributes.RestaurantsTableService attributes.WiFi attributes.BikeParking  \
# 0                               True          'free'                   True
# 1                         Not listed          'free'                  False
# 2                         Not listed            'no'                   True
# 3                         Not listed      Not listed             Not listed
# 4                              False          'free'                   True
#
#   attributes.BusinessAcceptsCreditCards attributes.RestaurantsReservations  \
# 0                                  True                              False
# 1                                  True                              False
# 2                            Not listed                               True
# 3                            Not listed                         Not listed
# 4                                  True                              False
#
#   attributes.WheelchairAccessible attributes.Caters attributes.OutdoorSeating  \
# 0                            True              True                      True
# 1                      Not listed              True                     False
# 2                      Not listed             False                     False
# 3                      Not listed        Not listed                Not listed
# 4                            True              True                      True
#
#   attributes.RestaurantsGoodForGroups attributes.HappyHour  \
# 0                                True                 True
# 1                               False           Not listed
# 2                                True           Not listed
# 3                          Not listed           Not listed
# 4                                True           Not listed
#
#   attributes.RestaurantsPriceRange2 attributes.HasTV attributes.Alcohol  \
# 0                                 2             True    'beer_and_wine'
# 1                                 2            False    'beer_and_wine'
# 2                                 2            False       'Not listed'
# 3                        Not listed       Not listed         Not listed
# 4                                 2             True       'Not listed'
#
#   attributes.DogsAllowed attributes.RestaurantsTakeOut attributes.NoiseLevel  \
# 0                  False                          True             'average'
# 1             Not listed                          True             'average'
# 2                  False                          True             'average'
# 3             Not listed                    Not listed            Not listed
# 4                   True                          True             'average'
#
#   attributes.RestaurantsAttire attributes.RestaurantsDelivery  \
# 0                     'casual'                     Not listed
# 1                     'casual'                          False
# 2                     'casual'                           True
# 3                   Not listed                     Not listed
# 4                     'casual'                           True
#
#   attributes.GoodForKids attributes.garage attributes.street  \
# 0             Not listed             False              True
# 1                   True              True             False
# 2                   True             False              True
# 3             Not listed        Not listed        Not listed
# 4                   True             False             False
#
#   attributes.validated attributes.lot attributes.valet attributes.touristy  \
# 0                False          False            False               False
# 1                False          False            False               False
# 2                False          False            False               False
# 3           Not listed     Not listed       Not listed          Not listed
# 4                False           True            False               False
#
#   attributes.hipster attributes.romantic attributes.divey attributes.intimate  \
# 0              False               False            False               False
# 1              False               False            False               False
# 2              False               False            False               False
# 3         Not listed          Not listed       Not listed          Not listed
# 4              False               False            False               False
#
#   attributes.trendy attributes.upscale attributes.classy attributes.casual  \
# 0             False              False             False              True
# 1             False              False             False              True
# 2             False              False             False              True
# 3        Not listed         Not listed        Not listed        Not listed
# 4             False              False             False              True
#
#   attributes.dessert attributes.latenight attributes.lunch attributes.dinner  \
# 0              False                False            False             False
# 1              False                False             True             False
# 2              False                False             True              True
# 3         Not listed           Not listed       Not listed        Not listed
# 4         Not listed           Not listed       Not listed        Not listed
#
#   attributes.brunch attributes.breakfast
# 0             False                False
# 1             False                 True
# 2             False                False
# 3        Not listed           Not listed
# 4        Not listed           Not listed

# %%
df_business.shape
# Out:
# (61328, 45)

# %%
# Create a csv file which consists of mostly the restaurants
df_business.to_csv('yelp_restaurants.csv', encoding='utf-8', index=False)
